# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML
import os

# %%
def display_csv_and_plot(csv_path='custom_results.csv', plot_path='custom_plot.png'):
    if not os.path.exists(csv_path):
        print(f"Файл {csv_path} не найден!")
        return
    if not os.path.exists(plot_path):
        print(f"Файл {plot_path} не найден!")
        return

    print("="*50)
    print(f"ДАННЫЕ ИЗ ФАЙЛА: {csv_path}")
    print("="*50)

    df = pd.read_csv(csv_path)

    print(df)

    print("\n" + "="*50)
    print(f"ГРАФИК ИЗ ФАЙЛА: {plot_path}")
    print("="*50)

    plt.figure(figsize=(12, 6))
    img = plt.imread(plot_path)
    plt.imshow(img)
    plt.axis('off')
    plt.tight_layout()
    plt.show()

    print("\n" + "="*50)
    print("АНАЛИТИКА ДАННЫХ")
    print("="*50)
    print(f"Всего тестов: {len(df)}")
    print(f"Среднее время: {df['Multiplication Time (s)'].mean():.2f} с")
    print(f"Максимальное время: {df['Multiplication Time (s)'].max():.3f} c (размер {df.loc[df['Multiplication Time (s)'].idxmax(), 'Dimension']})")
    print(f"Минимальное время: {df['Multiplication Time (s)'].min():.3f} c (размер {df.loc[df['Multiplication Time (s)'].idxmin(), 'Dimension']})")

# %%
display_csv_and_plot()
# Out:
# ==================================================
# ДАННЫЕ ИЗ ФАЙЛА: custom_results.csv
# ==================================================
#    Dimension  Multiplication Time (s)  Validation Result
# 0        100                    0.023               True
# 1        200                    0.188               True
# 2        300                    0.621               True
# 3        400                    1.455               True
# 4        500                    2.892               True
# 5        600                    5.077               True
# 6        700                    8.298               True
# 7        800                   12.423               True
# 8        900                   17.905               True
# 9       1000                   25.145               True
#
# ==================================================
# ГРАФИК ИЗ ФАЙЛА: custom_plot.png
# ==================================================
# ==================================================
# АНАЛИТИКА ДАННЫХ
# ==================================================
# Всего тестов: 10
# Среднее время: 7.40 с
# Максимальное время: 25.145 c (размер 1000)
# Минимальное время: 0.023 c (размер 100)
